# %% [markdown]
# Part A: In this first example, I used a similar setup to the tutorial example. I changed the beam length to 10, used 6 node tri element shape, adjusted the number of elements in the beam, increased the load, and increased the number of steps. The error between the analytical solution and the computed solution in this example is 3.716940e-03, showing a very good result for the solver under these conditions. ![IMG_6002.jpg](attachment:cebf160c-c3b9-4e6e-94a0-b62a2b21b333.jpg)

# %%
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis.solver import hyperelastic_solver
from finiteelementanalysis import visualize as viz
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %matplotlib inline

# Set up a 2D cantilever beam under a uniform downward traction on the top edge.
# The left edge (x=0) is clamped. For small deflection, compare the tip displacement
# at x=L, y=H/2 with the Euler–Bernoulli beam formula:
# For a cantilever of length L, height H, uniform load q, plane strain,
#   Material:
#         E = 1000, nu = 0.3.
#     Derived:
#         mu    = E/(2*(1+nu))
#         kappa = E/(3*(1-2*nu))
    
#     Analytical tip deflection for a cantilever beam under uniform load q is:
#         w(L) = q*L^4 / (8*E*I),   I = H^3/12.


# --- Beam geometry ---
L = 10.0   # length in x
H = 1.0    # height in y
nx = 40    # number of elements along length
ny = 4     # number of elements along height

ele_type = "D2_nn6_tri"  # 2D, 6-node tri 
ndof = 2                  # 2 DOFs per node (x, y)


coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)


# --- Identify boundaries ---
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(
    coords, connect, ele_type, x_lower=0.0, x_upper=L, y_lower=0.0, y_upper=H
)

# 1) Clamp the left edge: fix x- and y-displacements = 0
fixed_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)

# 2) Uniform downward traction on the top edge (y=H)
# Let q be negative in the y-direction
q = -0.01  # load per unit length in x
# For a 2D plane strain problem, this is a traction (tx, ty) = (0, q)
dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, q)

# Combine boundary conditions
fixed_nodes = fixed_left  # only the left edge is clamped

# --- Material properties ---
E = 1000.0
nu = 0.3
mu = E / (2.0 * (1.0 + nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))

material_props = np.array([mu, kappa])
print(f"Material properties: mu={mu:.3f}, kappa={kappa:.3f}")

# Number of incremental load steps
nr_num_steps = 5

# --- Solve with your hyperelastic solver ---
displacements_all, nr_info_all = hyperelastic_solver(
    material_props,
    ele_type,
    coords.T,      # shape (2, n_nodes)
    connect.T,     # shape (n_nodes_per_elem, n_elems)
    fixed_nodes,
    dload_info,
    nr_print=True,
    nr_num_steps=nr_num_steps,
    nr_tol=1e-10,
    nr_maxit=30,
)

final_disp = displacements_all[-1]  # shape: (n_nodes*ndof,)

# --- Compute the tip displacement from the FEA result ---
# We'll pick a node near x=L, y=H/2
tip_node = None
tol = 1e-3
for i, (x, y) in enumerate(coords):
    if abs(x - L) < tol and abs(y - H/2) < H/(2*ny):
        tip_node = i
        break
if tip_node is None:
    raise ValueError("Could not find tip node near x=L, y=H/2.")

tip_disp_y = final_disp[ndof*tip_node + 1]  # the y-component of displacement

# --- Compare with Euler–Bernoulli formula for small deflection ---
mu = material_props[0]
E_eff = E / (1 - nu ** 2.0)
I = H ** 3 / 12.0
w_analytical = q * L ** 4 / (8.0 * E_eff * I)

print(f"Tip node index: {tip_node}, coordinates={coords[tip_node]}")
print(f"Computed tip deflection (y): {tip_disp_y:.6f}")
print(f"Analytical Euler-Bernoulli deflection: {w_analytical:.6f}")

# --- Evaluate error ---
error = abs(tip_disp_y - w_analytical)
print(f"Absolute error = {error:.6e}")


# --- Plot the mesh with the final deformed shape ---
img_name = "full_code_example_2.gif"
viz.make_deformation_gif(displacements_all, coords, connect, ele_type, img_name)
from IPython.display import HTML, display

# Display animated GIF (correctly, looped)
display(HTML(f'<img src="{img_name}" width="600" loop>'))
# Out:
# Material properties: mu=384.615, kappa=833.333
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=1.613580e-06, tolerance=1.000000e-10
# Iteration 2, Correction=1.513276e-03, Residual=1.155399e-05, tolerance=1.000000e-10
# Iteration 3, Correction=4.067850e-06, Residual=8.061526e-11, tolerance=1.000000e-10
# Iteration 4, Correction=2.586165e-13, Residual=5.483277e-16, tolerance=1.000000e-10
# Step 1, load factor = 0.400
# Iteration 1, Correction=5.000997e-01, Residual=1.613580e-06, tolerance=1.000000e-10
# Iteration 2, Correction=7.559970e-04, Residual=1.157505e-05, tolerance=1.000000e-10
# Iteration 3, Correction=1.982232e-06, Residual=8.065701e-11, tolerance=1.000000e-10
# Iteration 4, Correction=1.471940e-13, Residual=5.513121e-16, tolerance=1.000000e-10
# Step 2, load factor = 0.600
# Iteration 1, Correction=3.335073e-01, Residual=1.613580e-06, tolerance=1.000000e-10
# Iteration 2, Correction=5.035797e-04, Residual=1.159555e-05, tolerance=1.000000e-10
# Iteration 3, Correction=1.286595e-06, Residual=8.069644e-11, tolerance=1.000000e-10
# Iteration 4, Correction=8.923738e-14, Residual=5.847746e-16, tolerance=1.000000e-10
# Step 3, load factor = 0.800
# Iteration 1, Correction=2.502159e-01, Residual=1.613580e-06, tolerance=1.000000e-10
# Iteration 2, Correction=3.773776e-04, Residual=1.161548e-05, tolerance=1.000000e-10
# Iteration 3, Correction=9.384605e-07, Residual=8.073363e-11, tolerance=1.000000e-10
# Iteration 4, Correction=5.964522e-14, Residual=6.019082e-16, tolerance=1.000000e-10
# Step 4, load factor = 1.000
# Iteration 1, Correction=2.002406e-01, Residual=1.613580e-06, tolerance=1.000000e-10
# Iteration 2, Correction=3.016617e-04, Residual=1.163484e-05, tolerance=1.000000e-10
# Iteration 3, Correction=7.293341e-07, Residual=8.076871e-11, tolerance=1.000000e-10
# Iteration 4, Correction=5.176209e-14, Residual=5.972645e-16, tolerance=1.000000e-10
# Tip node index: 404, coordinates=[10.   0.5]
# Computed tip deflection (y): -0.140217
# Analytical Euler-Bernoulli deflection: -0.136500
# Absolute error = 3.716940e-03
# <img src="full_code_example_2.gif" width="600" loop>

# %% [markdown]
# Part B: In this example, I have increased the uniform load across the bar from the above example to make this a large displacement. As you can see below, the analytical and computed displacements are now quite different. One of the issues here is shown in the mesh histograms below. One can see the aspect ratio of the selected mesh is far above the suggested upper limit. If you look at the example below this one, you will see I have adjusted the mesh to fix the aspect ratio problem. The result is a computed displacement far closer to the analytical displacement.

# %%
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis.solver import hyperelastic_solver
from finiteelementanalysis import visualize as viz
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %matplotlib inline

# Set up a 2D cantilever beam under a uniform downward traction on the top edge.
# The left edge (x=0) is clamped. For small deflection, compare the tip displacement
# at x=L, y=H/2 with the Euler–Bernoulli beam formula:
# For a cantilever of length L, height H, uniform load q, plane strain,
#   Material:
#         E = 1000, nu = 0.3.
#     Derived:
#         mu    = E/(2*(1+nu))
#         kappa = E/(3*(1-2*nu))
    
#     Analytical tip deflection for a cantilever beam under uniform load q is:
#         w(L) = q*L^4 / (8*E*I),   I = H^3/12.


# --- Beam geometry ---
L = 10.0   # length in x
H = 1.0    # height in y
nx = 2    # number of elements along length
ny = 2    # number of elements along height

ele_type = "D2_nn6_tri"  # 2D, 6-node tri 
ndof = 2                  # 2 DOFs per node (x, y)


coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)


# --- Identify boundaries ---
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(
    coords, connect, ele_type, x_lower=0.0, x_upper=L, y_lower=0.0, y_upper=H
)

# 1) Clamp the left edge: fix x- and y-displacements = 0
fixed_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)

# 2) Uniform downward traction on the top edge (y=H)
# Let q be negative in the y-direction
q = -.5  # load per unit length in x
# For a 2D plane strain problem, this is a traction (tx, ty) = (0, q)
dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, q)

# Combine boundary conditions
fixed_nodes = fixed_left  # only the left edge is clamped

# --- Material properties ---
E = 1000.0
nu = 0.3
mu = E / (2.0 * (1.0 + nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))

material_props = np.array([mu, kappa])
print(f"Material properties: mu={mu:.3f}, kappa={kappa:.3f}")

# Number of incremental load steps
nr_num_steps = 5

# --- Solve with your hyperelastic solver ---
displacements_all, nr_info_all = hyperelastic_solver(
    material_props,
    ele_type,
    coords.T,      # shape (2, n_nodes)
    connect.T,     # shape (n_nodes_per_elem, n_elems)
    fixed_nodes,
    dload_info,
    nr_print=True,
    nr_num_steps=nr_num_steps,
    nr_tol=1e-10,
    nr_maxit=30,
)

final_disp = displacements_all[-1]  # shape: (n_nodes*ndof,)

# --- Compute the tip displacement from the FEA result ---
# We'll pick a node near x=L, y=H/2
tip_node = None
tol = 1e-3
for i, (x, y) in enumerate(coords):
    if abs(x - L) < tol and abs(y - H/2) < H/(2*ny):
        tip_node = i
        break
if tip_node is None:
    raise ValueError("Could not find tip node near x=L, y=H/2.")

tip_disp_y = final_disp[ndof*tip_node + 1]  # the y-component of displacement

# --- Compare with Euler–Bernoulli formula for small deflection ---
mu = material_props[0]
E_eff = E / (1 - nu ** 2.0)
I = H ** 3 / 12.0
w_analytical = q * L ** 4 / (8.0 * E_eff * I)

print(f"Tip node index: {tip_node}, coordinates={coords[tip_node]}")
print(f"Computed tip deflection (y): {tip_disp_y:.6f}")
print(f"Analytical Euler-Bernoulli deflection: {w_analytical:.6f}")

# --- Evaluate error ---
error = abs(tip_disp_y - w_analytical)
print(f"Absolute error = {error:.6e}")


# --- Plot the mesh with the final deformed shape ---
img_name = "full_code_example_2.gif"
viz.make_deformation_gif(displacements_all, coords, connect, ele_type, img_name)
from IPython.display import HTML, display

# Display animated GIF (correctly, looped)
display(HTML(f'<img src="{img_name}" width="600" loop>'))

#-----

#num_gauss_pts = 3
mesh_name = "Beam"
#complex_outline = pre.get_bulldog_outline()
#mesh_size = 10.0
#coords, connect = pre.mesh_outline(complex_outline, ele_type, mesh_name, mesh_size)
#mesh_gauss_pts = pre_demo.get_all_mesh_gauss_pts(ele_type, num_gauss_pts, coords, connect)

# Create element quality historams
aspect_ratios, skewness, min_angles, max_angles = pre_demo.compute_element_quality_metrics(ele_type, coords, connect)
cond_nums, jac_dets = pre_demo.compute_condition_and_jacobian(ele_type, coords, connect)
plot_file = mesh_name + "_histograms"
pre_demo.plot_element_quality_histograms(
        fname=str(plot_file),
        super_title="Test Mesh Quality Metrics (%s)" % (ele_type),
        ele_type=ele_type,
        cond_nums=cond_nums,
        jac_dets=jac_dets,
        aspect_ratios=aspect_ratios,
        skewness=skewness,
        min_angles=min_angles,
        max_angles=max_angles
    )
from IPython.display import Image

# Display the saved histogram image
display(Image(filename=plot_file + ".png"))
# Out:
# Material properties: mu=384.615, kappa=833.333
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=1.013794e-02, tolerance=1.000000e-10
# Iteration 2, Correction=7.189071e-02, Residual=3.390331e+00, tolerance=1.000000e-10
# Iteration 3, Correction=8.769824e-03, Residual=5.290370e-02, tolerance=1.000000e-10
# Iteration 4, Correction=3.725431e-03, Residual=4.157929e-04, tolerance=1.000000e-10
# Iteration 5, Correction=1.075469e-05, Residual=5.838684e-05, tolerance=1.000000e-10
# Iteration 6, Correction=4.729159e-09, Residual=5.270573e-10, tolerance=1.000000e-10
# Iteration 7, Correction=1.845499e-15, Residual=9.321256e-14, tolerance=1.000000e-10
# Step 1, load factor = 0.400
# Iteration 1, Correction=4.962640e-01, Residual=1.013794e-02, tolerance=1.000000e-10
# Iteration 2, Correction=3.553111e-02, Residual=3.321261e+00, tolerance=1.000000e-10
# Iteration 3, Correction=1.468494e-02, Residual=5.092726e-02, tolerance=1.000000e-10
# Iteration 4, Correction=4.236114e-03, Residual=2.647236e-03, tolerance=1.000000e-10
# Iteration 5, Correction=7.405373e-05, Residual=2.824162e-04, tolerance=1.000000e-10
# Iteration 6, Correction=1.403082e-07, Residual=8.508859e-08, tolerance=1.000000e-10
# Iteration 7, Correction=8.632064e-14, Residual=4.138671e-13, tolerance=1.000000e-10
# Step 2, load factor = 0.600
# Iteration 1, Correction=3.124231e-01, Residual=1.013794e-02, tolerance=1.000000e-10
# Iteration 2, Correction=2.030565e-02, Residual=2.635475e+00, tolerance=1.000000e-10
# Iteration 3, Correction=1.667686e-02, Residual=3.253894e-02, tolerance=1.000000e-10
# Iteration 4, Correction=2.839382e-03, Residual=7.464035e-03, tolerance=1.000000e-10
# Iteration 5, Correction=1.260636e-04, Residual=2.648045e-04, tolerance=1.000000e-10
# Iteration 6, Correction=2.040832e-07, Residual=5.194032e-07, tolerance=1.000000e-10
# Iteration 7, Correction=6.551970e-13, Residual=1.398834e-12, tolerance=1.000000e-10
# Step 3, load factor = 0.800
# Iteration 1, Correction=2.138351e-01, Residual=1.013794e-02, tolerance=1.000000e-10
# Iteration 2, Correction=1.219003e-02, Residual=1.891375e+00, tolerance=1.000000e-10
# Iteration 3, Correction=1.297232e-02, Residual=1.715334e-02, tolerance=1.000000e-10
# Iteration 4, Correction=1.089382e-03, Residual=7.515237e-03, tolerance=1.000000e-10
# Iteration 5, Correction=4.356894e-05, Residual=6.305823e-05, tolerance=1.000000e-10
# Iteration 6, Correction=1.533899e-08, Residual=1.016979e-07, tolerance=1.000000e-10
# Iteration 7, Correction=7.510345e-15, Residual=3.368521e-13, tolerance=1.000000e-10
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.548545e-01, Residual=1.013794e-02, tolerance=1.000000e-10
# Iteration 2, Correction=7.825747e-03, Residual=1.332133e+00, tolerance=1.000000e-10
# Iteration 3, Correction=8.867544e-03, Residual=8.822612e-03, tolerance=1.000000e-10
# Iteration 4, Correction=3.639537e-04, Residual=5.086714e-03, tolerance=1.000000e-10
# Iteration 5, Correction=8.872930e-06, Residual=1.000115e-05, tolerance=1.000000e-10
# Iteration 6, Correction=4.570137e-10, Residual=6.043665e-09, tolerance=1.000000e-10
# Iteration 7, Correction=3.256312e-15, Residual=3.743089e-13, tolerance=1.000000e-10
# Tip node index: 14, coordinates=[10.   0.5]
# Computed tip deflection (y): -5.006476
# Analytical Euler-Bernoulli deflection: -6.825000
# Absolute error = 1.818524e+00
# <img src="full_code_example_2.gif" width="600" loop>

# %% [markdown]
# Part B continued: Below I adjust the mesh to fix the aspect ratio issue noted above. This results in a much closer match between the analytical and computed solutions to this problem.

# %%
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis.solver import hyperelastic_solver
from finiteelementanalysis import visualize as viz
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %matplotlib inline

# Set up a 2D cantilever beam under a uniform downward traction on the top edge.
# The left edge (x=0) is clamped. For small deflection, compare the tip displacement
# at x=L, y=H/2 with the Euler–Bernoulli beam formula:
# For a cantilever of length L, height H, uniform load q, plane strain,
#   Material:
#         E = 1000, nu = 0.3.
#     Derived:
#         mu    = E/(2*(1+nu))
#         kappa = E/(3*(1-2*nu))
    
#     Analytical tip deflection for a cantilever beam under uniform load q is:
#         w(L) = q*L^4 / (8*E*I),   I = H^3/12.


# --- Beam geometry ---
L = 10.0   # length in x
H = 1.0    # height in y
nx = 20    # number of elements along length
ny = 2    # number of elements along height

ele_type = "D2_nn6_tri"  # 2D, 6-node tri 
ndof = 2                  # 2 DOFs per node (x, y)


coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)


# --- Identify boundaries ---
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(
    coords, connect, ele_type, x_lower=0.0, x_upper=L, y_lower=0.0, y_upper=H
)

# 1) Clamp the left edge: fix x- and y-displacements = 0
fixed_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)

# 2) Uniform downward traction on the top edge (y=H)
# Let q be negative in the y-direction
q = -.5  # load per unit length in x
# For a 2D plane strain problem, this is a traction (tx, ty) = (0, q)
dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, q)

# Combine boundary conditions
fixed_nodes = fixed_left  # only the left edge is clamped

# --- Material properties ---
E = 1000.0
nu = 0.3
mu = E / (2.0 * (1.0 + nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))

material_props = np.array([mu, kappa])
print(f"Material properties: mu={mu:.3f}, kappa={kappa:.3f}")

# Number of incremental load steps
nr_num_steps = 5

# --- Solve with your hyperelastic solver ---
displacements_all, nr_info_all = hyperelastic_solver(
    material_props,
    ele_type,
    coords.T,      # shape (2, n_nodes)
    connect.T,     # shape (n_nodes_per_elem, n_elems)
    fixed_nodes,
    dload_info,
    nr_print=True,
    nr_num_steps=nr_num_steps,
    nr_tol=1e-10,
    nr_maxit=30,
)

final_disp = displacements_all[-1]  # shape: (n_nodes*ndof,)

# --- Compute the tip displacement from the FEA result ---
# We'll pick a node near x=L, y=H/2
tip_node = None
tol = 1e-3
for i, (x, y) in enumerate(coords):
    if abs(x - L) < tol and abs(y - H/2) < H/(2*ny):
        tip_node = i
        break
if tip_node is None:
    raise ValueError("Could not find tip node near x=L, y=H/2.")

tip_disp_y = final_disp[ndof*tip_node + 1]  # the y-component of displacement

# --- Compare with Euler–Bernoulli formula for small deflection ---
mu = material_props[0]
E_eff = E / (1 - nu ** 2.0)
I = H ** 3 / 12.0
w_analytical = q * L ** 4 / (8.0 * E_eff * I)

print(f"Tip node index: {tip_node}, coordinates={coords[tip_node]}")
print(f"Computed tip deflection (y): {tip_disp_y:.6f}")
print(f"Analytical Euler-Bernoulli deflection: {w_analytical:.6f}")

# --- Evaluate error ---
error = abs(tip_disp_y - w_analytical)
print(f"Absolute error = {error:.6e}")


# --- Plot the mesh with the final deformed shape ---
img_name = "full_code_example_2.gif"
viz.make_deformation_gif(displacements_all, coords, connect, ele_type, img_name)
from IPython.display import HTML, display

# Display animated GIF (correctly, looped)
display(HTML(f'<img src="{img_name}" width="600" loop>'))

#-----


mesh_name = "Beam"


# Create element quality historams
aspect_ratios, skewness, min_angles, max_angles = pre_demo.compute_element_quality_metrics(ele_type, coords, connect)
cond_nums, jac_dets = pre_demo.compute_condition_and_jacobian(ele_type, coords, connect)
plot_file = mesh_name + "_histograms"
pre_demo.plot_element_quality_histograms(
        fname=str(plot_file),
        super_title="Test Mesh Quality Metrics (%s)" % (ele_type),
        ele_type=ele_type,
        cond_nums=cond_nums,
        jac_dets=jac_dets,
        aspect_ratios=aspect_ratios,
        skewness=skewness,
        min_angles=min_angles,
        max_angles=max_angles
    )
from IPython.display import Image

# Display the saved histogram image
display(Image(filename=plot_file + ".png"))
# Out:
# Material properties: mu=384.615, kappa=833.333
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=4.049768e-04, tolerance=1.000000e-10
# Iteration 2, Correction=7.604346e-02, Residual=1.619644e-01, tolerance=1.000000e-10
# Iteration 3, Correction=1.191626e-02, Residual=2.834730e-03, tolerance=1.000000e-10
# Iteration 4, Correction=6.590395e-03, Residual=3.763431e-05, tolerance=1.000000e-10
# Iteration 5, Correction=4.554005e-05, Residual=1.059940e-05, tolerance=1.000000e-10
# Iteration 6, Correction=9.253712e-08, Residual=5.429129e-10, tolerance=1.000000e-10
# Iteration 7, Correction=8.465449e-15, Residual=5.596048e-15, tolerance=1.000000e-10
# Step 1, load factor = 0.400
# Iteration 1, Correction=5.001566e-01, Residual=4.049768e-04, tolerance=1.000000e-10
# Iteration 2, Correction=3.841647e-02, Residual=1.659153e-01, tolerance=1.000000e-10
# Iteration 3, Correction=4.718003e-03, Residual=2.977286e-03, tolerance=1.000000e-10
# Iteration 4, Correction=1.795948e-03, Residual=1.297094e-05, tolerance=1.000000e-10
# Iteration 5, Correction=3.939340e-06, Residual=2.914782e-06, tolerance=1.000000e-10
# Iteration 6, Correction=1.989944e-09, Residual=1.501073e-11, tolerance=1.000000e-10
# Iteration 7, Correction=1.801320e-16, Residual=9.745987e-15, tolerance=1.000000e-10
# Step 2, load factor = 0.600
# Iteration 1, Correction=3.243825e-01, Residual=4.049768e-04, tolerance=1.000000e-10
# Iteration 2, Correction=2.358613e-02, Residual=1.471994e-01, tolerance=1.000000e-10
# Iteration 3, Correction=9.217210e-03, Residual=2.352816e-03, tolerance=1.000000e-10
# Iteration 4, Correction=3.079679e-03, Residual=1.205011e-04, tolerance=1.000000e-10
# Iteration 5, Correction=6.381901e-05, Residual=1.896425e-05, tolerance=1.000000e-10
# Iteration 6, Correction=2.024251e-07, Residual=8.101362e-09, tolerance=1.000000e-10
# Iteration 7, Correction=2.818275e-13, Residual=8.621191e-14, tolerance=1.000000e-10
# Step 3, load factor = 0.800
# Iteration 1, Correction=2.293719e-01, Residual=4.049768e-04, tolerance=1.000000e-10
# Iteration 2, Correction=1.502737e-02, Residual=1.169072e-01, tolerance=1.000000e-10
# Iteration 3, Correction=1.000344e-02, Residual=1.491466e-03, tolerance=1.000000e-10
# Iteration 4, Correction=1.994775e-03, Residual=2.502142e-04, tolerance=1.000000e-10
# Iteration 5, Correction=7.875098e-05, Residual=1.324140e-05, tolerance=1.000000e-10
# Iteration 6, Correction=1.615138e-07, Residual=2.072289e-08, tolerance=1.000000e-10
# Iteration 7, Correction=5.308916e-13, Residual=9.267244e-14, tolerance=1.000000e-10
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.695335e-01, Residual=4.049768e-04, tolerance=1.000000e-10
# Iteration 2, Correction=9.756555e-03, Residual=8.699914e-02, tolerance=1.000000e-10
# Iteration 3, Correction=8.861656e-03, Residual=8.303459e-04, tolerance=1.000000e-10
# Iteration 4, Correction=9.197549e-04, Residual=2.916269e-04, tolerance=1.000000e-10
# Iteration 5, Correction=3.844242e-05, Residual=4.049042e-06, tolerance=1.000000e-10
# Iteration 6, Correction=2.221011e-08, Residual=7.200936e-09, tolerance=1.000000e-10
# Iteration 7, Correction=2.461667e-14, Residual=1.823808e-14, tolerance=1.000000e-10
# Tip node index: 122, coordinates=[10.   0.5]
# Computed tip deflection (y): -5.881359
# Analytical Euler-Bernoulli deflection: -6.825000
# Absolute error = 9.436414e-01
# <img src="full_code_example_2.gif" width="600" loop>

# %% [markdown]
# Part C: In this last example, the uniform load across the beam was too great and led to the solver failing. The solver fails because the number of incremental load steps is too low for such a large, load which leads to an invalid determinant. This error can be solved by increasing the number of incremental steps the solver uses. Below this example, i have increased the number of steps to 50, which allows the solver to compute the displacement.

# %%
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis.solver import hyperelastic_solver
from finiteelementanalysis import visualize as viz
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %matplotlib inline

# Set up a 2D cantilever beam under a uniform downward traction on the top edge.
# The left edge (x=0) is clamped. For small deflection, compare the tip displacement
# at x=L, y=H/2 with the Euler–Bernoulli beam formula:
# For a cantilever of length L, height H, uniform load q, plane strain,
#   Material:
#         E = 1000, nu = 0.3.
#     Derived:
#         mu    = E/(2*(1+nu))
#         kappa = E/(3*(1-2*nu))
    
#     Analytical tip deflection for a cantilever beam under uniform load q is:
#         w(L) = q*L^4 / (8*E*I),   I = H^3/12.


# --- Beam geometry ---
L = 10.0   # length in x
H = 1.0    # height in y
nx = 10    # number of elements along length
ny = 4     # number of elements along height

ele_type = "D2_nn6_tri"  # 2D, 6-node tri 
ndof = 2                  # 2 DOFs per node (x, y)


coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)


# --- Identify boundaries ---
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(
    coords, connect, ele_type, x_lower=0.0, x_upper=L, y_lower=0.0, y_upper=H
)

# 1) Clamp the left edge: fix x- and y-displacements = 0
fixed_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)

# 2) Uniform downward traction on the top edge (y=H)
# Let q be negative in the y-direction
q = -10  # load per unit length in x
# For a 2D plane strain problem, this is a traction (tx, ty) = (0, q)
dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, q)

# Combine boundary conditions
fixed_nodes = fixed_left  # only the left edge is clamped

# --- Material properties ---
E = 1000.0
nu = 0.3
mu = E / (2.0 * (1.0 + nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))

material_props = np.array([mu, kappa])
print(f"Material properties: mu={mu:.3f}, kappa={kappa:.3f}")

# Number of incremental load steps
nr_num_steps = 5

# --- Solve with your hyperelastic solver ---
displacements_all, nr_info_all = hyperelastic_solver(
    material_props,
    ele_type,
    coords.T,      # shape (2, n_nodes)
    connect.T,     # shape (n_nodes_per_elem, n_elems)
    fixed_nodes,
    dload_info,
    nr_print=True,
    nr_num_steps=nr_num_steps,
    nr_tol=1e-10,
    nr_maxit=30,
)

final_disp = displacements_all[-1]  # shape: (n_nodes*ndof,)

# --- Compute the tip displacement from the FEA result ---
# We'll pick a node near x=L, y=H/2
tip_node = None
tol = 1e-3
for i, (x, y) in enumerate(coords):
    if abs(x - L) < tol and abs(y - H/2) < H/(2*ny):
        tip_node = i
        break
if tip_node is None:
    raise ValueError("Could not find tip node near x=L, y=H/2.")

tip_disp_y = final_disp[ndof*tip_node + 1]  # the y-component of displacement

# --- Compare with Euler–Bernoulli formula for small deflection ---
mu = material_props[0]
E_eff = E / (1 - nu ** 2.0)
I = H ** 3 / 12.0
w_analytical = q * L ** 4 / (8.0 * E_eff * I)

print(f"Tip node index: {tip_node}, coordinates={coords[tip_node]}")
print(f"Computed tip deflection (y): {tip_disp_y:.6f}")
print(f"Analytical Euler-Bernoulli deflection: {w_analytical:.6f}")

# --- Evaluate error ---
error = abs(tip_disp_y - w_analytical)
print(f"Absolute error = {error:.6e}")


# --- Plot the mesh with the final deformed shape ---
img_name = "full_code_example_2.gif"
viz.make_deformation_gif(displacements_all, coords, connect, ele_type, img_name)
from IPython.display import HTML, display

# Display animated GIF (correctly, looped)
display(HTML(f'<img src="{img_name}" width="600" loop>'))
# Out:
# Material properties: mu=384.615, kappa=833.333
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=1.237713e-02, tolerance=1.000000e-10
# Iteration 2, Correction=4.337877e-01, Residual=2.673737e+02, tolerance=1.000000e-10
# C:\Users\tsand\Downloads\SunAssignment-3-main (3)\Assignment-3-main\src\finiteelementanalysis\solver.py:133: MatrixRankWarning: Matrix is exactly singular
#   d_displacement = spla.spsolve(K_sparse, R)
# C:\Users\tsand\anaconda3.1\envs\tl_Assignment3-env\Lib\site-packages\numpy\linalg\_linalg.py:2432: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# Iteration 3, Correction=0.000000e+00, Residual=nan, tolerance=1.000000e-10
# Step 1, load factor = 0.400
# Iteration 1, Correction=0.000000e+00, Residual=nan, tolerance=1.000000e-10
# Step 2, load factor = 0.600
# Iteration 1, Correction=0.000000e+00, Residual=nan, tolerance=1.000000e-10
# Step 3, load factor = 0.800
# Iteration 1, Correction=0.000000e+00, Residual=nan, tolerance=1.000000e-10
# Step 4, load factor = 1.000
# Iteration 1, Correction=0.000000e+00, Residual=nan, tolerance=1.000000e-10
# Tip node index: 104, coordinates=[10.   0.5]
# Computed tip deflection (y): nan
# Analytical Euler-Bernoulli deflection: -136.500000
# Absolute error = nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 113
#     111 # --- Plot the mesh with the final deformed shape ---
#     112 img_name = "full_code_example_2.gif"
# --> 113 viz.make_deformation_gif(displacements_all, coords, connect, ele_type, img_name)
#     114 from IPython.display import HTML, display
#     116 # Display animated GIF (correctly, looped)
#
# File ~\Downloads\SunAssignment-3-main (3)\Assignment-3-main\src\finiteelementanalysis\visualize.py:110, in make_deformation_gif(displacements_all, coords, connect, ele_type, gif_path, magnification, interval)
#     108 x_min, x_max = coords[:, 0].min() - max_disp, coords[:, 0].max() + max_disp
#     109 y_min, y_max = coords[:, 1].min() - max_disp, coords[:, 1].max() + max_disp
# --> 110 ax.set_xlim(x_min, x_max)
#     111 ax.set_ylim(y_min, y_max)
#     113 # Compute global maximum displacement magnitude
#
# File ~\anaconda3.1\envs\tl_Assignment3-env\Lib\site-packages\matplotlib\axes\_base.py:3812, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3810         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3811     right = xmax
# -> 3812 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File ~\anaconda3.1\envs\tl_Assignment3-env\Lib\site-packages\matplotlib\axis.py:1216, in Axis._set_lim(self, v0, v1, emit, auto)
#    1213 name = self._get_axis_name()
#    1215 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# -> 1216 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1217 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1219 if v0 is None or v1 is None:
#    1220     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    1221     # so only grab the limits if we really need them.
#
# File ~\anaconda3.1\envs\tl_Assignment3-env\Lib\site-packages\matplotlib\axes\_base.py:3733, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3730     converted_limit = converted_limit.squeeze()
#    3731 if (isinstance(converted_limit, Real)
#    3732         and not np.isfinite(converted_limit)):
# -> 3733     raise ValueError("Axis limits cannot be NaN or Inf")
#    3734 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf

# %% [markdown]
# Part C continued: I have now increased the number of incremental steps to 50 which fixes the previous error, though the computed and analytical results are still far from realistic given the geometric limitations of the problem.

# %%
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis.solver import hyperelastic_solver
from finiteelementanalysis import visualize as viz
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %matplotlib inline

# Set up a 2D cantilever beam under a uniform downward traction on the top edge.
# The left edge (x=0) is clamped. For small deflection, compare the tip displacement
# at x=L, y=H/2 with the Euler–Bernoulli beam formula:
# For a cantilever of length L, height H, uniform load q, plane strain,
#   Material:
#         E = 1000, nu = 0.3.
#     Derived:
#         mu    = E/(2*(1+nu))
#         kappa = E/(3*(1-2*nu))
    
#     Analytical tip deflection for a cantilever beam under uniform load q is:
#         w(L) = q*L^4 / (8*E*I),   I = H^3/12.


# --- Beam geometry ---
L = 10.0   # length in x
H = 1.0    # height in y
nx = 10    # number of elements along length
ny = 4     # number of elements along height

ele_type = "D2_nn6_tri"  # 2D, 6-node tri 
ndof = 2                  # 2 DOFs per node (x, y)


coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)


# --- Identify boundaries ---
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(
    coords, connect, ele_type, x_lower=0.0, x_upper=L, y_lower=0.0, y_upper=H
)

# 1) Clamp the left edge: fix x- and y-displacements = 0
fixed_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)

# 2) Uniform downward traction on the top edge (y=H)
# Let q be negative in the y-direction
q = -10  # load per unit length in x
# For a 2D plane strain problem, this is a traction (tx, ty) = (0, q)
dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, q)

# Combine boundary conditions
fixed_nodes = fixed_left  # only the left edge is clamped

# --- Material properties ---
E = 1000.0
nu = 0.3
mu = E / (2.0 * (1.0 + nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))

material_props = np.array([mu, kappa])
print(f"Material properties: mu={mu:.3f}, kappa={kappa:.3f}")

# Number of incremental load steps
nr_num_steps = 50

# --- Solve with your hyperelastic solver ---
displacements_all, nr_info_all = hyperelastic_solver(
    material_props,
    ele_type,
    coords.T,      # shape (2, n_nodes)
    connect.T,     # shape (n_nodes_per_elem, n_elems)
    fixed_nodes,
    dload_info,
    nr_print=True,
    nr_num_steps=nr_num_steps,
    nr_tol=1e-10,
    nr_maxit=30,
)

final_disp = displacements_all[-1]  # shape: (n_nodes*ndof,)

# --- Compute the tip displacement from the FEA result ---
# We'll pick a node near x=L, y=H/2
tip_node = None
tol = 1e-3
for i, (x, y) in enumerate(coords):
    if abs(x - L) < tol and abs(y - H/2) < H/(2*ny):
        tip_node = i
        break
if tip_node is None:
    raise ValueError("Could not find tip node near x=L, y=H/2.")

tip_disp_y = final_disp[ndof*tip_node + 1]  # the y-component of displacement

# --- Compare with Euler–Bernoulli formula for small deflection ---
mu = material_props[0]
E_eff = E / (1 - nu ** 2.0)
I = H ** 3 / 12.0
w_analytical = q * L ** 4 / (8.0 * E_eff * I)

print(f"Tip node index: {tip_node}, coordinates={coords[tip_node]}")
print(f"Computed tip deflection (y): {tip_disp_y:.6f}")
print(f"Analytical Euler-Bernoulli deflection: {w_analytical:.6f}")

# --- Evaluate error ---
error = abs(tip_disp_y - w_analytical)
print(f"Absolute error = {error:.6e}")


# --- Plot the mesh with the final deformed shape ---
img_name = "full_code_example_2.gif"
viz.make_deformation_gif(displacements_all, coords, connect, ele_type, img_name)
from IPython.display import HTML, display

# Display animated GIF (correctly, looped)
display(HTML(f'<img src="{img_name}" width="600" loop>'))
# Out:
# Material properties: mu=384.615, kappa=833.333
# Step 0, load factor = 0.020
# Iteration 1, Correction=1.000000e+00, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.397109e-01, Residual=8.801248e-01, tolerance=1.000000e-10
# Iteration 3, Correction=8.170697e-03, Residual=4.960573e-02, tolerance=1.000000e-10
# Iteration 4, Correction=2.760129e-02, Residual=2.622666e-04, tolerance=1.000000e-10
# Iteration 5, Correction=6.814372e-04, Residual=9.874146e-04, tolerance=1.000000e-10
# Iteration 6, Correction=8.067603e-05, Residual=7.429695e-07, tolerance=1.000000e-10
# Iteration 7, Correction=6.334050e-09, Residual=8.328781e-09, tolerance=1.000000e-10
# Iteration 8, Correction=6.737411e-15, Residual=3.729459e-14, tolerance=1.000000e-10
# Step 1, load factor = 0.040
# Iteration 1, Correction=4.918129e-01, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=6.587200e-02, Residual=8.137179e-01, tolerance=1.000000e-10
# Iteration 3, Correction=1.111878e-02, Residual=4.290846e-02, tolerance=1.000000e-10
# Iteration 4, Correction=2.245050e-02, Residual=3.933303e-04, tolerance=1.000000e-10
# Iteration 5, Correction=6.441126e-04, Residual=1.971865e-03, tolerance=1.000000e-10
# Iteration 6, Correction=1.183664e-04, Residual=2.027950e-06, tolerance=1.000000e-10
# Iteration 7, Correction=2.433383e-08, Residual=6.239245e-08, tolerance=1.000000e-10
# Iteration 8, Correction=1.519070e-13, Residual=6.613483e-14, tolerance=1.000000e-10
# Step 2, load factor = 0.060
# Iteration 1, Correction=2.948437e-01, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=3.195946e-02, Residual=5.006377e-01, tolerance=1.000000e-10
# Iteration 3, Correction=1.535095e-02, Residual=1.703330e-02, tolerance=1.000000e-10
# Iteration 4, Correction=1.516716e-02, Residual=1.170195e-03, tolerance=1.000000e-10
# Iteration 5, Correction=1.241276e-03, Residual=1.846646e-03, tolerance=1.000000e-10
# Iteration 6, Correction=1.869292e-04, Residual=1.199907e-05, tolerance=1.000000e-10
# Iteration 7, Correction=2.013519e-07, Residual=3.062917e-07, tolerance=1.000000e-10
# Iteration 8, Correction=5.357727e-12, Residual=3.680656e-13, tolerance=1.000000e-10
# Step 3, load factor = 0.080
# Iteration 1, Correction=1.893122e-01, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.567504e-02, Residual=2.697221e-01, tolerance=1.000000e-10
# Iteration 3, Correction=1.564846e-02, Residual=5.087986e-03, tolerance=1.000000e-10
# Iteration 4, Correction=4.314283e-03, Residual=2.050902e-03, tolerance=1.000000e-10
# Iteration 5, Correction=6.312838e-04, Residual=2.251679e-04, tolerance=1.000000e-10
# Iteration 6, Correction=1.046260e-05, Residual=4.932096e-06, tolerance=1.000000e-10
# Iteration 7, Correction=3.932148e-09, Residual=1.478200e-09, tolerance=1.000000e-10
# Iteration 8, Correction=8.083081e-16, Residual=7.171685e-14, tolerance=1.000000e-10
# Step 4, load factor = 0.100
# Iteration 1, Correction=1.292671e-01, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=8.406620e-03, Residual=1.470938e-01, tolerance=1.000000e-10
# Iteration 3, Correction=1.125294e-02, Residual=1.557064e-03, tolerance=1.000000e-10
# Iteration 4, Correction=9.072466e-04, Residual=1.477142e-03, tolerance=1.000000e-10
# Iteration 5, Correction=8.421477e-05, Residual=1.313257e-05, tolerance=1.000000e-10
# Iteration 6, Correction=7.282837e-08, Residual=1.205692e-07, tolerance=1.000000e-10
# Iteration 7, Correction=5.821807e-13, Residual=1.294521e-13, tolerance=1.000000e-10
# Step 5, load factor = 0.120
# Iteration 1, Correction=9.323067e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=5.172303e-03, Residual=8.452010e-02, tolerance=1.000000e-10
# Iteration 3, Correction=6.921159e-03, Residual=5.711485e-04, tolerance=1.000000e-10
# Iteration 4, Correction=1.885936e-04, Residual=6.993453e-04, tolerance=1.000000e-10
# Iteration 5, Correction=7.189157e-06, Residual=7.192375e-07, tolerance=1.000000e-10
# Iteration 6, Correction=3.032327e-10, Residual=1.110772e-09, tolerance=1.000000e-10
# Iteration 7, Correction=6.533258e-16, Residual=7.686323e-14, tolerance=1.000000e-10
# Step 6, load factor = 0.140
# Iteration 1, Correction=7.033503e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=3.687280e-03, Residual=5.139850e-02, tolerance=1.000000e-10
# Iteration 3, Correction=4.036487e-03, Residual=2.732023e-04, tolerance=1.000000e-10
# Iteration 4, Correction=4.541894e-05, Residual=2.812452e-04, tolerance=1.000000e-10
# Iteration 5, Correction=6.039448e-07, Residual=5.224918e-08, tolerance=1.000000e-10
# Iteration 6, Correction=1.638452e-12, Residual=9.435210e-12, tolerance=1.000000e-10
# Step 7, load factor = 0.160
# Iteration 1, Correction=5.501273e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=2.916974e-03, Residual=3.293049e-02, tolerance=1.000000e-10
# Iteration 3, Correction=2.295099e-03, Residual=1.617366e-04, tolerance=1.000000e-10
# Iteration 4, Correction=1.325268e-05, Residual=1.033175e-04, tolerance=1.000000e-10
# Iteration 5, Correction=5.748579e-08, Residual=5.269972e-09, tolerance=1.000000e-10
# Iteration 6, Correction=1.427186e-14, Residual=1.544055e-13, tolerance=1.000000e-10
# Step 8, load factor = 0.180
# Iteration 1, Correction=4.429494e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=2.413900e-03, Residual=2.209797e-02, tolerance=1.000000e-10
# Iteration 3, Correction=1.285362e-03, Residual=1.063459e-04, tolerance=1.000000e-10
# Iteration 4, Correction=4.419790e-06, Residual=3.566314e-05, tolerance=1.000000e-10
# Iteration 5, Correction=6.096211e-09, Residual=6.478604e-10, tolerance=1.000000e-10
# Iteration 6, Correction=1.869448e-16, Residual=9.459507e-14, tolerance=1.000000e-10
# Step 9, load factor = 0.200
# Iteration 1, Correction=3.651621e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=2.017521e-03, Residual=1.544890e-02, tolerance=1.000000e-10
# Iteration 3, Correction=7.161595e-04, Residual=7.278558e-05, tolerance=1.000000e-10
# Iteration 4, Correction=1.563764e-06, Residual=1.186344e-05, tolerance=1.000000e-10
# Iteration 5, Correction=6.753999e-10, Residual=8.618580e-11, tolerance=1.000000e-10
# Iteration 6, Correction=2.247315e-16, Residual=1.095799e-13, tolerance=1.000000e-10
# Step 10, load factor = 0.220
# Iteration 1, Correction=3.069437e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.683770e-03, Residual=1.120134e-02, tolerance=1.000000e-10
# Iteration 3, Correction=4.012018e-04, Residual=5.044605e-05, tolerance=1.000000e-10
# Iteration 4, Correction=5.653141e-07, Residual=3.901489e-06, tolerance=1.000000e-10
# Iteration 5, Correction=7.608843e-11, Residual=1.177507e-11, tolerance=1.000000e-10
# Step 11, load factor = 0.240
# Iteration 1, Correction=2.622337e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.402763e-03, Residual=8.390604e-03, tolerance=1.000000e-10
# Iteration 3, Correction=2.280377e-04, Residual=3.511596e-05, tolerance=1.000000e-10
# Iteration 4, Correction=2.074426e-07, Residual=1.296053e-06, tolerance=1.000000e-10
# Iteration 5, Correction=8.794810e-12, Residual=1.648498e-12, tolerance=1.000000e-10
# Step 12, load factor = 0.260
# Iteration 1, Correction=2.271402e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.169847e-03, Residual=6.471291e-03, tolerance=1.000000e-10
# Iteration 3, Correction=1.323320e-04, Residual=2.456572e-05, tolerance=1.000000e-10
# Iteration 4, Correction=7.771823e-08, Residual=4.415989e-07, tolerance=1.000000e-10
# Iteration 5, Correction=1.063598e-12, Residual=2.529981e-13, tolerance=1.000000e-10
# Step 13, load factor = 0.280
# Iteration 1, Correction=1.990759e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=9.792503e-04, Residual=5.122954e-03, tolerance=1.000000e-10
# Iteration 3, Correction=7.868761e-05, Residual=1.732650e-05, tolerance=1.000000e-10
# Iteration 4, Correction=2.995113e-08, Residual=1.557933e-07, tolerance=1.000000e-10
# Iteration 5, Correction=1.370687e-13, Residual=1.361464e-13, tolerance=1.000000e-10
# Step 14, load factor = 0.300
# Iteration 1, Correction=1.762681e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=8.242922e-04, Residual=4.150836e-03, tolerance=1.000000e-10
# Iteration 3, Correction=4.802067e-05, Residual=1.235971e-05, tolerance=1.000000e-10
# Iteration 4, Correction=1.193902e-08, Residual=5.720091e-08, tolerance=1.000000e-10
# Iteration 5, Correction=1.884239e-14, Residual=1.249435e-13, tolerance=1.000000e-10
# Step 15, load factor = 0.320
# Iteration 1, Correction=1.574697e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=6.984533e-04, Residual=3.433001e-03, tolerance=1.000000e-10
# Iteration 3, Correction=3.008523e-05, Residual=8.936657e-06, tolerance=1.000000e-10
# Iteration 4, Correction=4.938117e-09, Residual=2.190811e-08, tolerance=1.000000e-10
# Iteration 5, Correction=2.778070e-15, Residual=1.182467e-13, tolerance=1.000000e-10
# Step 16, load factor = 0.340
# Iteration 1, Correction=1.417830e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=5.960060e-04, Residual=2.891069e-03, tolerance=1.000000e-10
# Iteration 3, Correction=1.934006e-05, Residual=6.557693e-06, tolerance=1.000000e-10
# Iteration 4, Correction=2.122117e-09, Residual=8.759950e-09, tolerance=1.000000e-10
# Iteration 5, Correction=4.845709e-16, Residual=1.317161e-13, tolerance=1.000000e-10
# Step 17, load factor = 0.360
# Iteration 1, Correction=1.285484e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=5.122065e-04, Residual=2.473456e-03, tolerance=1.000000e-10
# Iteration 3, Correction=1.274452e-05, Residual=4.886052e-06, tolerance=1.000000e-10
# Iteration 4, Correction=9.476614e-10, Residual=3.657284e-09, tolerance=1.000000e-10
# Iteration 5, Correction=3.130525e-16, Residual=1.421035e-13, tolerance=1.000000e-10
# Step 18, load factor = 0.380
# Iteration 1, Correction=1.172726e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=4.432496e-04, Residual=2.145481e-03, tolerance=1.000000e-10
# Iteration 3, Correction=8.598666e-06, Residual=3.696555e-06, tolerance=1.000000e-10
# Iteration 4, Correction=4.395110e-10, Residual=1.594461e-09, tolerance=1.000000e-10
# Iteration 5, Correction=1.633238e-16, Residual=1.214011e-13, tolerance=1.000000e-10
# Step 19, load factor = 0.400
# Iteration 1, Correction=1.075805e-02, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=3.861318e-04, Residual=1.883364e-03, tolerance=1.000000e-10
# Iteration 3, Correction=5.932193e-06, Residual=2.838735e-06, tolerance=1.000000e-10
# Iteration 4, Correction=2.115005e-10, Residual=7.261680e-10, tolerance=1.000000e-10
# Iteration 5, Correction=3.628227e-16, Residual=1.334005e-13, tolerance=1.000000e-10
# Step 20, load factor = 0.420
# Iteration 1, Correction=9.918294e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=3.384989e-04, Residual=1.670494e-03, tolerance=1.000000e-10
# Iteration 3, Correction=4.179231e-06, Residual=2.211603e-06, tolerance=1.000000e-10
# Iteration 4, Correction=1.054855e-10, Residual=3.457955e-10, tolerance=1.000000e-10
# Iteration 5, Correction=1.575237e-16, Residual=1.515439e-13, tolerance=1.000000e-10
# Step 21, load factor = 0.440
# Iteration 1, Correction=9.185396e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=2.985071e-04, Residual=1.495068e-03, tolerance=1.000000e-10
# Iteration 3, Correction=3.002600e-06, Residual=1.746847e-06, tolerance=1.000000e-10
# Iteration 4, Correction=5.446174e-11, Residual=1.723615e-10, tolerance=1.000000e-10
# Step 22, load factor = 0.460
# Iteration 1, Correction=8.541501e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=2.647097e-04, Residual=1.348557e-03, tolerance=1.000000e-10
# Iteration 3, Correction=2.197124e-06, Residual=1.397808e-06, tolerance=1.000000e-10
# Iteration 4, Correction=2.907178e-11, Residual=9.005644e-11, tolerance=1.000000e-10
# Step 23, load factor = 0.480
# Iteration 1, Correction=7.972346e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=2.359662e-04, Residual=1.224704e-03, tolerance=1.000000e-10
# Iteration 3, Correction=1.635393e-06, Residual=1.132272e-06, tolerance=1.000000e-10
# Iteration 4, Correction=1.602457e-11, Residual=4.932873e-11, tolerance=1.000000e-10
# Step 24, load factor = 0.500
# Iteration 1, Correction=7.466428e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=2.113729e-04, Residual=1.118848e-03, tolerance=1.000000e-10
# Iteration 3, Correction=1.236733e-06, Residual=9.277385e-07, tolerance=1.000000e-10
# Iteration 4, Correction=9.108715e-12, Residual=2.831063e-11, tolerance=1.000000e-10
# Step 25, load factor = 0.520
# Iteration 1, Correction=7.014388e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.902095e-04, Residual=1.027470e-03, tolerance=1.000000e-10
# Iteration 3, Correction=9.491114e-07, Residual=7.683117e-07, tolerance=1.000000e-10
# Iteration 4, Correction=5.332312e-12, Residual=1.698209e-11, tolerance=1.000000e-10
# Step 26, load factor = 0.540
# Iteration 1, Correction=6.608550e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.718979e-04, Residual=9.478766e-04, tolerance=1.000000e-10
# Iteration 3, Correction=7.383651e-07, Residual=6.426301e-07, tolerance=1.000000e-10
# Iteration 4, Correction=3.210123e-12, Residual=1.060737e-11, tolerance=1.000000e-10
# Step 27, load factor = 0.560
# Iteration 1, Correction=6.242571e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.559715e-04, Residual=8.779801e-04, tolerance=1.000000e-10
# Iteration 3, Correction=5.816885e-07, Residual=5.424806e-07, tolerance=1.000000e-10
# Iteration 4, Correction=1.984418e-12, Residual=6.860006e-12, tolerance=1.000000e-10
# Step 28, load factor = 0.580
# Iteration 1, Correction=5.911174e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.420511e-04, Residual=8.161455e-04, tolerance=1.000000e-10
# Iteration 3, Correction=4.636116e-07, Residual=4.618598e-07, tolerance=1.000000e-10
# Iteration 4, Correction=1.257779e-12, Residual=4.582171e-12, tolerance=1.000000e-10
# Step 29, load factor = 0.600
# Iteration 1, Correction=5.609939e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.298271e-04, Residual=7.610767e-04, tolerance=1.000000e-10
# Iteration 3, Correction=3.734813e-07, Residual=3.963318e-07, tolerance=1.000000e-10
# Iteration 4, Correction=8.159742e-13, Residual=3.147214e-12, tolerance=1.000000e-10
# Step 30, load factor = 0.620
# Iteration 1, Correction=5.335146e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.190446e-04, Residual=7.117364e-04, tolerance=1.000000e-10
# Iteration 3, Correction=3.038557e-07, Residual=3.425845e-07, tolerance=1.000000e-10
# Iteration 4, Correction=5.410728e-13, Residual=2.202924e-12, tolerance=1.000000e-10
# Step 31, load factor = 0.640
# Iteration 1, Correction=5.083641e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.094933e-04, Residual=6.672866e-04, tolerance=1.000000e-10
# Iteration 3, Correction=2.494645e-07, Residual=2.981201e-07, tolerance=1.000000e-10
# Iteration 4, Correction=3.659520e-13, Residual=1.578751e-12, tolerance=1.000000e-10
# Step 32, load factor = 0.660
# Iteration 1, Correction=4.852740e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=1.009981e-04, Residual=6.270438e-04, tolerance=1.000000e-10
# Iteration 3, Correction=2.065273e-07, Residual=2.610365e-07, tolerance=1.000000e-10
# Iteration 4, Correction=2.523109e-13, Residual=1.149088e-12, tolerance=1.000000e-10
# Step 33, load factor = 0.680
# Iteration 1, Correction=4.640146e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=9.341312e-05, Residual=5.904463e-04, tolerance=1.000000e-10
# Iteration 3, Correction=1.722988e-07, Residual=2.298718e-07, tolerance=1.000000e-10
# Iteration 4, Correction=1.768501e-13, Residual=8.524515e-13, tolerance=1.000000e-10
# Step 34, load factor = 0.700
# Iteration 1, Correction=4.443885e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=8.661574e-05, Residual=5.570285e-04, tolerance=1.000000e-10
# Iteration 3, Correction=1.447620e-07, Residual=2.034925e-07, tolerance=1.000000e-10
# Iteration 4, Correction=1.259796e-13, Residual=6.455425e-13, tolerance=1.000000e-10
# Step 35, load factor = 0.720
# Iteration 1, Correction=4.262251e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=8.050270e-05, Residual=5.264018e-04, tolerance=1.000000e-10
# Iteration 3, Correction=1.224189e-07, Residual=1.810122e-07, tolerance=1.000000e-10
# Iteration 4, Correction=9.108982e-14, Residual=5.027639e-13, tolerance=1.000000e-10
# Step 36, load factor = 0.740
# Iteration 1, Correction=4.093766e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=7.498661e-05, Residual=4.982394e-04, tolerance=1.000000e-10
# Iteration 3, Correction=1.041449e-07, Residual=1.617321e-07, tolerance=1.000000e-10
# Iteration 4, Correction=6.664370e-14, Residual=3.953874e-13, tolerance=1.000000e-10
# Step 37, load factor = 0.760
# Iteration 1, Correction=3.937142e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=6.999321e-05, Residual=4.722645e-04, tolerance=1.000000e-10
# Iteration 3, Correction=8.908753e-08, Residual=1.450972e-07, tolerance=1.000000e-10
# Iteration 4, Correction=4.941970e-14, Residual=3.096221e-13, tolerance=1.000000e-10
# Step 38, load factor = 0.780
# Iteration 1, Correction=3.791253e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=6.545913e-05, Residual=4.482415e-04, tolerance=1.000000e-10
# Iteration 3, Correction=7.659426e-08, Residual=1.306633e-07, tolerance=1.000000e-10
# Iteration 4, Correction=3.678431e-14, Residual=2.586426e-13, tolerance=1.000000e-10
# Step 39, load factor = 0.800
# Iteration 1, Correction=3.655111e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=6.133012e-05, Residual=4.259683e-04, tolerance=1.000000e-10
# Iteration 3, Correction=6.616133e-08, Residual=1.180726e-07, tolerance=1.000000e-10
# Iteration 4, Correction=2.792039e-14, Residual=2.456699e-13, tolerance=1.000000e-10
# Step 40, load factor = 0.820
# Iteration 1, Correction=3.527845e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=5.755957e-05, Residual=4.052704e-04, tolerance=1.000000e-10
# Iteration 3, Correction=5.739636e-08, Residual=1.070349e-07, tolerance=1.000000e-10
# Iteration 4, Correction=2.129674e-14, Residual=2.012611e-13, tolerance=1.000000e-10
# Step 41, load factor = 0.840
# Iteration 1, Correction=3.408686e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=5.410727e-05, Residual=3.859966e-04, tolerance=1.000000e-10
# Iteration 3, Correction=4.999128e-08, Residual=9.731327e-08, tolerance=1.000000e-10
# Iteration 4, Correction=1.636471e-14, Residual=2.021576e-13, tolerance=1.000000e-10
# Step 42, load factor = 0.860
# Iteration 1, Correction=3.296951e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=5.093846e-05, Residual=3.680152e-04, tolerance=1.000000e-10
# Iteration 3, Correction=4.370235e-08, Residual=8.871324e-08, tolerance=1.000000e-10
# Iteration 4, Correction=1.266090e-14, Residual=1.986575e-13, tolerance=1.000000e-10
# Step 43, load factor = 0.880
# Iteration 1, Correction=3.192033e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=4.802293e-05, Residual=3.512103e-04, tolerance=1.000000e-10
# Iteration 3, Correction=3.833528e-08, Residual=8.107417e-08, tolerance=1.000000e-10
# Iteration 4, Correction=9.954337e-15, Residual=1.941864e-13, tolerance=1.000000e-10
# Step 44, load factor = 0.900
# Iteration 1, Correction=3.093389e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=4.533439e-05, Residual=3.354802e-04, tolerance=1.000000e-10
# Iteration 3, Correction=3.373413e-08, Residual=7.426264e-08, tolerance=1.000000e-10
# Iteration 4, Correction=7.809584e-15, Residual=1.576203e-13, tolerance=1.000000e-10
# Step 45, load factor = 0.920
# Iteration 1, Correction=3.000533e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=4.284989e-05, Residual=3.207347e-04, tolerance=1.000000e-10
# Iteration 3, Correction=2.977288e-08, Residual=6.816724e-08, tolerance=1.000000e-10
# Iteration 4, Correction=6.236972e-15, Residual=1.763019e-13, tolerance=1.000000e-10
# Step 46, load factor = 0.940
# Iteration 1, Correction=2.913027e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=4.054928e-05, Residual=3.068935e-04, tolerance=1.000000e-10
# Iteration 3, Correction=2.634909e-08, Residual=6.269447e-08, tolerance=1.000000e-10
# Iteration 4, Correction=4.897486e-15, Residual=1.927518e-13, tolerance=1.000000e-10
# Step 47, load factor = 0.960
# Iteration 1, Correction=2.830479e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=3.841490e-05, Residual=2.938850e-04, tolerance=1.000000e-10
# Iteration 3, Correction=2.337892e-08, Residual=5.776548e-08, tolerance=1.000000e-10
# Iteration 4, Correction=4.008600e-15, Residual=1.655254e-13, tolerance=1.000000e-10
# Step 48, load factor = 0.980
# Iteration 1, Correction=2.752533e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=3.643114e-05, Residual=2.816450e-04, tolerance=1.000000e-10
# Iteration 3, Correction=2.079342e-08, Residual=5.331339e-08, tolerance=1.000000e-10
# Iteration 4, Correction=3.294358e-15, Residual=1.445698e-13, tolerance=1.000000e-10
# Step 49, load factor = 1.000
# Iteration 1, Correction=2.678865e-03, Residual=1.237713e-03, tolerance=1.000000e-10
# Iteration 2, Correction=3.458422e-05, Residual=2.701157e-04, tolerance=1.000000e-10
# Iteration 3, Correction=1.853553e-08, Residual=4.928124e-08, tolerance=1.000000e-10
# Iteration 4, Correction=2.569366e-15, Residual=1.669143e-13, tolerance=1.000000e-10
# Tip node index: 104, coordinates=[10.   0.5]
# Computed tip deflection (y): -10.088300
# Analytical Euler-Bernoulli deflection: -136.500000
# Absolute error = 1.264117e+02
# <img src="full_code_example_2.gif" width="600" loop>
